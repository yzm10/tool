# %% [markdown]
# <a href="https://colab.research.google.com/github/yzm10/tool/blob/main/drawing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# encoding=utf-8
import matplotlib.pyplot as plt
from pylab import *                                 #支持中文
mpl.rcParams['font.sans-serif'] = ['SimHei']

x = [16, 32, 64, 96]
y1 = [9.123-1.3, 8.762-1.3, 8.634-1.3, 8.583-1.3]
y = [7.765, 7.379, 7.277, 7.272]
#plt.plot(x, y, 'ro-')
#plt.plot(x, y1, 'bo-')
plt.xlim(12, 100)  # 限定横轴的范围
plt.ylim(7, 8)  # 限定纵轴的范围
plt.plot(x, y1, marker='o', mec='r', mfc='w',label=u'PS-FCN - 1.3')
plt.plot(x, y, marker='*', ms=10,label=u'Ours')
plt.legend()  # 让图例生效
plt.xticks(x, names, rotation=0)
plt.margins(0)
plt.subplots_adjust(bottom=0.15)
plt.xlabel(u"T e s t") #X轴标签
plt.ylabel("M A E") #Y轴标签
plt.title("Input 16") #标题

plt.show()

# %%
# encoding=utf-8
import matplotlib.pyplot as plt
from pylab import *                                 #支持中文
mpl.rcParams['font.sans-serif'] = ['SimHei']

x = [16, 32, 64, 96]
y1 = [9.223-1, 8.688-1, 8.459-1, 8.394-1]
y = [8.078, 7.587, 7.415, 7.384]
#plt.plot(x, y, 'ro-')
#plt.plot(x, y1, 'bo-')
plt.xlim(12, 100)  # 限定横轴的范围
plt.ylim(7, 9)  # 限定纵轴的范围
plt.plot(x, y1, marker='o', mec='r', mfc='w',label=u'PS-FCN - 1')
plt.plot(x, y, marker='*', ms=10,label=u'Ours')
plt.legend()  # 让图例生效
plt.xticks(x, names, rotation=0)
plt.margins(0)
plt.subplots_adjust(bottom=0.15)
plt.xlabel(u"T e s t") #X轴标签
plt.ylabel("M A E") #Y轴标签
plt.title("Input 32") #标题

plt.show()

# %%
# encoding=utf-8
import matplotlib.pyplot as plt
from pylab import *                                 #支持中文
mpl.rcParams['font.sans-serif'] = ['SimHei']

x = [16, 32, 64, 96]
y1 = [9.932-1, 9.229-1, 8.921-1, 8.865-1]
y = [8.466, 8.018, 7.863, 7.872]
#plt.plot(x, y, 'ro-')
#plt.plot(x, y1, 'bo-')
plt.xlim(12, 100)  # 限定横轴的范围
plt.ylim(7.5, 9.5)  # 限定纵轴的范围
plt.plot(x, y1, marker='o', mec='r', mfc='w',label=u'PS-FCN - 1')
plt.plot(x, y, marker='*', ms=10,label=u'Ours')
plt.legend()  # 让图例生效
plt.xticks(x, names, rotation=0)
plt.margins(0)
plt.subplots_adjust(bottom=0.15)
plt.xlabel(u"T e s t") #X轴标签
plt.ylabel("M A E") #Y轴标签
plt.title("Input 48") #标题

plt.show()

# %%
# encoding=utf-8
import matplotlib.pyplot as plt
from pylab import *                                 #支持中文
mpl.rcParams['font.sans-serif'] = ['SimHei']

import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = fig.gca(projection='3d')

x1 = [16, 32, 64, 96]

y11 = [9.123-1.3, 8.762-1.3, 8.634-1.3, 8.583-1.3]
y1 = [7.765, 7.379, 7.277, 7.272]
z1 = [16,16,16,16]

y21 = [9.223-1, 8.688-1, 8.459-1, 8.394-1]
y2 = [8.078, 7.587, 7.415, 7.384]
z2 = [32,32,32,32]

y31 = [9.932-1, 9.229-1, 8.921-1, 8.865-1]
y3 = [8.466, 8.018, 7.863, 7.872]
z3 = [48,48,48,48]
x=[16, 32, 64, 96,16, 32, 64, 96,16, 32, 64, 96]
y01=[9.123-1, 8.762-1, 8.634-1, 8.583-1,9.223-1, 8.688-1, 8.459-1, 8.394-1,9.932-1, 9.229-1, 8.921-1, 8.865-1]
y0=[7.765, 7.379, 7.277, 7.272,8.078, 7.587, 7.415, 7.384,8.466, 8.018, 7.863, 7.872]
z=[16,16,16,16,32,32,32,32,48,48,48,48]
#plt.plot(x, y, 'ro-')
#plt.plot(x, y1, 'bo-')
# plt.xlim(12, 100)  # 限定横轴的范围
# plt.ylim(7.5, 9.5)  # 限定纵轴的范围
ax.plot(z, x, y01, marker='o', mec='r', mfc='w',label=u'PS-FCN - 1')
ax.plot(z, x, y0, marker='*', ms=10,label=u'Ours')
ax.legend()  # 让图例生效
# plt.xticks(x, names, rotation=0)
# plt.margins(0)
# plt.subplots_adjust(bottom=0.15)
# plt.xlabel(u"T e s t") #X轴标签
ax.set_xlabel("Input") #X轴标签
ax.set_ylabel("Test")
ax.set_zlabel("MAE")
# plt.ylabel("M A E") #Y轴标签
# plt.title("Input 48") #标题

plt.show()
